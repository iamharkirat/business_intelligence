# %% [markdown]
# <a href="https://colab.research.google.com/github/iamharkirat/business_intelligence/blob/main/Google_Causal_Impact.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Libraries and Dates

# %%
#install libraries
# !pip install yfinance
# !pip install tfcausalimpact
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.10/dist-packages (0.2.31)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.5.3)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.23.5)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.9.3)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2023.3.post1)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.3.8)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.10/dist-packages (from yfinance) (3.17.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.11.2)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2023.7.22)
# Collecting tfcausalimpact
#   Downloading tfcausalimpact-0.0.13-py3-none-any.whl (38 kB)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from tfcausalimpact) (3.1.2)
# Requirement already satisfied: pandas>=1.3.5 in /usr/local/lib/python3.10/dist-packages (from tfcausalimpact) (1.5.3)
# Requirement already satisfied: tensorflow>=2.10 in /usr/local/lib/python3.10/dist-packages (from tfcausalimpact) (2.14.0)
# Requirement already satisfied: tensorflow-probability>=0.18 in /usr/local/lib/python3.10/dist-packages (from tfcausalimpact) (0.22.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from tfcausalimpact) (3.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.5->tfcausalimpact) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.5->tfcausalimpact) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.5->tfcausalimpact) (1.23.5)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.10->tfcausalimpact) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.10->tfcausalimpact) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.10->tfcausalimpact) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.10->tfcausalimpact) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.10->tfcausalimpact) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.10->tfcausalimpact) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.10->tfcausalimpact) (16.0.6)
# Requirement already satisfied: ml-dtypes==0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.10->tfcausalimpact) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.10->tfcausalimpact) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.10->tfcausalimpact) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.10->tfcausalimpact) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.10->tfcausalimpact) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.10->tfcausalimpact) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.10->tfcausalimpact) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.10->tfcausalimpact) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.10->tfcausalimpact) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.10->tfcausalimpact) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.10->tfcausalimpact) (1.59.2)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.10->tfcausalimpact) (2.14.1)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.10->tfcausalimpact) (2.14.0)
# Requirement already satisfied: keras<2.15,>=2.14.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.10->tfcausalimpact) (2.14.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from tensorflow-probability>=0.18->tfcausalimpact) (4.4.2)
# Requirement already satisfied: cloudpickle>=1.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow-probability>=0.18->tfcausalimpact) (2.2.1)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.10/dist-packages (from tensorflow-probability>=0.18->tfcausalimpact) (0.1.8)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->tfcausalimpact) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->tfcausalimpact) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->tfcausalimpact) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->tfcausalimpact) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->tfcausalimpact) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->tfcausalimpact) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->tfcausalimpact) (3.1.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow>=2.10->tfcausalimpact) (0.41.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow>=2.10->tfcausalimpact) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow>=2.10->tfcausalimpact) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow>=2.10->tfcausalimpact) (3.5.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow>=2.10->tfcausalimpact) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow>=2.10->tfcausalimpact) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow>=2.10->tfcausalimpact) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow>=2.10->tfcausalimpact) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow>=2.10->tfcausalimpact) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow>=2.10->tfcausalimpact) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow>=2.10->tfcausalimpact) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow>=2.10->tfcausalimpact) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow>=2.10->tfcausalimpact) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow>=2.10->tfcausalimpact) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow>=2.10->tfcausalimpact) (2023.7.22)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow>=2.10->tfcausalimpact) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow>=2.10->tfcausalimpact) (3.2.2)
# Installing collected packages: tfcausalimpact
# Successfully installed tfcausalimpact-0.0.13

# %%
#import libraries
import yfinance as yf
from causalimpact import CausalImpact
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Dates
training_start = "2020-09-01"
training_end = "2020-10-19"
treatment_start = "2020-10-20"
treatment_end = "2020-10-23"
end_stock = "2020-10-24"

# %% [markdown]
# #Loading financial data

# %%
#Bitcoin
y = ["BTC-USD"]
y = yf.download(tickers = y,
                start = training_start,
                end = end_stock,
                interval = "1d")
y = y['Adj Close'].rename("y")
y[:1]
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Date
# 2020-09-01    11970.478516
# Name: y, dtype: float64

# %%
#Load more stock data
stocks = ["ZAL.DE", "SQ", "CRSP", "TRMB", "JD", "DE", "KTOS", "GOOG"]
X = yf.download(tickers = stocks,
                start = training_start,
                end = end_stock,
                interval = "1d")
# Out:
# [*********************100%%**********************]  8 of 8 completed

# %% [markdown]
# #Data Preparation

# %%
#Getting the adjusted close
X = X.iloc[:, :len(stocks)]
X.head(1)
# Out:
#             Adj Close                                                         \
#                  CRSP          DE     GOOG         JD       KTOS          SQ
# Date
# 2020-09-01  93.419998  209.291977  83.0355  79.267685  19.700001  166.660004
#
#
#              TRMB ZAL.DE
# Date
# 2020-09-01  53.41   77.0

# %%
#Removing level
X.columns = X.columns.droplevel()
X.head(1)
# Out:
#                  CRSP          DE     GOOG         JD       KTOS          SQ  \
# Date
# 2020-09-01  93.419998  209.291977  83.0355  79.267685  19.700001  166.660004
#
#              TRMB  ZAL.DE
# Date
# 2020-09-01  53.41    77.0

# %%
#Time zones
X.index = X.index.tz_localize(None)
X.index
# Out:
# DatetimeIndex(['2020-09-01', '2020-09-02', '2020-09-03', '2020-09-04',
#                '2020-09-07', '2020-09-08', '2020-09-09', '2020-09-10',
#                '2020-09-11', '2020-09-14', '2020-09-15', '2020-09-16',
#                '2020-09-17', '2020-09-18', '2020-09-21', '2020-09-22',
#                '2020-09-23', '2020-09-24', '2020-09-25', '2020-09-28',
#                '2020-09-29', '2020-09-30', '2020-10-01', '2020-10-02',
#                '2020-10-05', '2020-10-06', '2020-10-07', '2020-10-08',
#                '2020-10-09', '2020-10-12', '2020-10-13', '2020-10-14',
#                '2020-10-15', '2020-10-16', '2020-10-19', '2020-10-20',
#                '2020-10-21', '2020-10-22', '2020-10-23'],
#               dtype='datetime64[ns]', name='Date', freq='B')

# %%
#Combine everything
df = pd.concat([y, X], axis = 1).dropna()
df.head()
# Out:
#                        y       CRSP          DE       GOOG         JD  \
# Date
# 2020-09-01  11970.478516  93.419998  209.291977  83.035500  79.267685
# 2020-09-02  11414.034180  93.930000  208.734344  86.414001  79.959564
# 2020-09-03  10245.296875  85.690002  202.677383  82.092003  75.952454
# 2020-09-04  10511.813477  82.019997  203.186951  79.552002  76.874954
# 2020-09-08  10131.516602  81.459999  202.129379  76.619499  73.242615
#
#                  KTOS          SQ       TRMB     ZAL.DE
# Date
# 2020-09-01  19.700001  166.660004  53.410000  77.000000
# 2020-09-02  19.910000  162.880005  54.310001  77.000000
# 2020-09-03  19.520000  152.860001  50.900002  75.080002
# 2020-09-04  19.260000  146.389999  49.959999  71.739998
# 2020-09-08  19.230000  139.110001  49.139999  73.440002

# %% [markdown]
# #Data Analysis section

# %%
#Prepare a dataframe with only training data
df_training = df[df.index <= training_end]
df_training.tail()
# Out:
#                        y        CRSP          DE       GOOG         JD  \
# Date
# 2020-10-13  11425.899414  103.059998  228.852371  78.584000  79.382996
# 2020-10-14  11429.506836  101.370003  230.058273  78.403999  77.931984
# 2020-10-15  11495.349609   99.889999  229.836380  77.956497  77.115181
# 2020-10-16  11322.123047  109.830002  231.592178  78.650497  78.335571
# 2020-10-19  11742.037109  107.720001  229.768860  76.730499  77.461121
#
#                  KTOS          SQ       TRMB     ZAL.DE
# Date
# 2020-10-13  20.959999  190.470001  51.720001  85.820000
# 2020-10-14  21.010000  187.490005  50.540001  84.980003
# 2020-10-15  21.100000  188.600006  52.290001  84.419998
# 2020-10-16  20.790001  186.350006  52.340000  84.800003
# 2020-10-19  20.639999  186.960007  51.970001  85.000000

# %%
#Stationarity
from statsmodels.tsa.stattools import adfuller
test = adfuller(x = df_training.y)[1]

#how to read - ifelse
if test < 0.05:
  print("The Time Series is stationary")
else:
  print("The Time Series is not stationary")
# Out:
# The Time Series is not stationary

# %%
differencing = df_training.pct_change().dropna()
differencing.head()
# Out:
#                    y      CRSP        DE      GOOG        JD      KTOS  \
# Date
# 2020-09-02 -0.046485  0.005459 -0.002664  0.040687  0.008728  0.010660
# 2020-09-03 -0.102395 -0.087725 -0.029018 -0.050015 -0.050114 -0.019588
# 2020-09-04  0.026014 -0.042829  0.002514 -0.030941  0.012146 -0.013320
# 2020-09-08 -0.036178 -0.006828 -0.005205 -0.036863 -0.047250 -0.001558
# 2020-09-09  0.010939  0.046526  0.025114  0.016034  0.012726  0.016641
#
#                   SQ      TRMB    ZAL.DE
# Date
# 2020-09-02 -0.022681  0.016851  0.000000
# 2020-09-03 -0.061518 -0.062788 -0.024935
# 2020-09-04 -0.042326 -0.018468 -0.044486
# 2020-09-08 -0.049730 -0.016413  0.023697
# 2020-09-09  0.036662  0.019740 -0.009804

# %%
#Stationarity
from statsmodels.tsa.stattools import adfuller
test = adfuller(x = differencing.y)[1]

#how to read - ifelse
if test < 0.05:
  print("The Time Series is stationary")
else:
  print("The Time Series is not stationary")
# Out:
# The Time Series is stationary

# %%
#Correlation Matrix
plt.figure(figsize = (12,10))
sns.set(font_scale = 1.2)
sns.heatmap(differencing.corr(),
            annot = True,
            fmt = '.1g',
            cmap = 'YlOrBr',
            center =  True,
            linewidth = 1,
            linecolor = 'black')
plt.show()

# %% [markdown]
# #Causal Impact

# %%
df_final = df.drop(columns = ["ZAL.DE"])
df_final.head(1)
# Out:
#                        y       CRSP          DE     GOOG         JD  \
# Date
# 2020-09-01  11970.478516  93.419998  209.291977  83.0355  79.267685
#
#                  KTOS          SQ   TRMB
# Date
# 2020-09-01  19.700001  166.660004  53.41

# %%
#Pre and post period
pre_period = [training_start, training_end]
post_period = [treatment_start, treatment_end]

# %%
#Google causal impact
impact = CausalImpact(data=df_final,
                      pre_period = pre_period,
                      post_period = post_period)
impact.plot()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py:459: StructuralTimeSeries.joint_log_prob (from tensorflow_probability.python.sts.structural_time_series) is deprecated and will be removed after 2022-03-01.
# Instructions for updating:
# Please use `StructuralTimeSeries.joint_distribution(observed_time_series).log_prob`
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/causalimpact/model.py:408: calling one_step_predictive (from tensorflow_probability.python.sts.forecast) with timesteps_are_event_shape=True is deprecated and will be removed after 2021-12-31.
# Instructions for updating:
# `Predictive distributions returned by`tfp.sts.one_step_predictive` will soon compute per-timestep probabilities (treating timesteps as part of the batch shape) instead of a single probability for an entire series (the current approach, in which timesteps are treated as event shape). Please update your code to pass `timesteps_are_event_shape=False` (this will soon be the default) and to explicitly sum over the per-timestep log probabilities if this is required.

# %%
#Summary
print(impact.summary())
#1634
# Out:
# Posterior Inference {Causal Impact}
#                           Average            Cumulative
# Actual                    12659.36           50637.45
# Prediction (s.d.)         11050.38 (200.7)   44201.53 (802.81)
# 95% CI                    [10681.41, 11468.15][42725.66, 45872.6]
#
# Absolute effect (s.d.)    1608.98 (200.7)    6435.93 (802.81)
# 95% CI                    [1191.21, 1977.95] [4764.85, 7911.79]
#
# Relative effect (s.d.)    14.56% (1.82%)     14.56% (1.82%)
# 95% CI                    [10.78%, 17.9%]    [10.78%, 17.9%]
#
# Posterior tail-area probability p: 0.0
# Posterior prob. of a causal effect: 100.0%
#
# For more details run the command: print(impact.summary('report'))

# %%
#Summary report
print(impact.summary('report'))
# Out:
# Analysis report {CausalImpact}
#
#
# During the post-intervention period, the response variable had
# an average value of approx. 12659.36. By contrast, in the absence of an
# intervention, we would have expected an average response of 11317.08.
# The 95% interval of this counterfactual prediction is [10874.85, 11814.93].
# Subtracting this prediction from the observed response yields
# an estimate of the causal effect the intervention had on the
# response variable. This effect is 1342.28 with a 95% interval of
# [844.44, 1784.51]. For a discussion of the significance of this effect,
# see below.
#
#
# Summing up the individual data points during the post-intervention
# period (which can only sometimes be meaningfully interpreted), the
# response variable had an overall value of 50637.45.
# By contrast, had the intervention not taken place, we would have expected
# a sum of 45268.32. The 95% interval of this prediction is [43499.4, 47259.7].
#
#
# The above results are given in terms of absolute numbers. In relative
# terms, the response variable showed an increase of +11.86%. The 95%
# interval of this percentage is [7.46%, 15.77%].
#
#
# This means that the positive effect observed during the intervention
# period is statistically significant and unlikely to be due to random
# fluctuations. It should be noted, however, that the question of whether
# this increase also bears substantive significance can only be answered
# by comparing the absolute effect (1342.28) to the original goal
# of the underlying intervention.
#
#
# The probability of obtaining this effect by chance is very small
# (Bayesian one-sided tail-area probability p = 0.0).
# This means the causal effect can be considered statistically
# significant.
